# %% [markdown]
# # Week2授業前課題1

# %% [markdown]
# ## 【課題】統計基礎用語の説明
# ___

# %% [markdown]
# Q1. 標準偏差について、分散との違いや関係性、どんな時に使う指標なのかをお答えください。
# A1. 標準偏差$\sigma$は、分散$\sigma^2$の関係がある。あるデータ群が与えられた時に、そのデータがどのくらいのばらついているかを表す指標
#
#
# Q2. 共分散行列について述べてください。
# A2.　変数$X_{1}$, $X_{2}$, ..., $X_{n}$と
# それらの期待値(平均値)$E[X_{1}]$, $E[X_{2}]$, ..., $E[X_{n}]$に対して、
# 変数$X_i$と$X_j$の共分散は$\sigma_{ij} = E[(X_{i} - E[X_{i}])(X_{j} - E[X_{j}])]$と定義される。
# $(i, j)$成分が$\sigma_{ij}$である様な行列を共分散行列という
#
# Q3. 1次元の正規分布と多次元の正規分布について述べてください。特にどういう時に使うのかについてお答えください。
#
# A3. 正規分布は確率分布の一種。多くの事象は正規分布様のデータ分布を示す。

# %% [markdown]
# ## 【課題】データ点の作成
# ___

# %%
import numpy.random as rnd
import matplotlib.pyplot as plt

mu_1 = [-3, 0]
mu_2 = [0, -3]
sigma = [
    [1, 0.8],
    [0.8, 1.0]
]

data1 = rnd.multivariate_normal(mu_1, sigma, 500 )
data2 = rnd.multivariate_normal(mu_2, sigma, 500 )

# %%
data1[0:5]
# Out:
# array([[-3.99782365, -0.90064673,  1.        ],
#        [-3.86847907, -0.0421917 ,  1.        ],
#        [-1.5168245 ,  2.77122821,  1.        ],
#        [-1.83888502,  1.44637252,  1.        ],
#        [-3.27093107, -0.28313191,  1.        ]])

# %%
data2[0:5]
# Out:
# array([[ 1.89114607, -1.89919823,  0.        ],
#        [ 0.58613958, -2.29648764,  0.        ],
#        [ 0.60864571, -3.28072248,  0.        ],
#        [ 1.25410013, -1.22946846,  0.        ],
#        [ 0.95478737, -2.28929021,  0.        ]])

# %% [markdown]
# ## 【課題】データ点へのラベル付け

# %%
label1 = np.full((500,1), 1)
label2 = np.full((500, 1), 0)

# %%
label1[0:5]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [1]])

# %%
label2[0:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
data1 = np.concatenate((data1, label1), axis = 1)
data2 = np.concatenate((data2, label2), axis=1)

data3 = np.concatenate((data1, data2), axis =0 )

# %% [markdown]
# ## 【課題】正しくラベル付けされているか見てみる
# ___

# %%
import matplotlib.pyplot as plt

plt.scatter(data3[:, 0], data3[:, 1], s=10, c=data3[:, 2])
plt.show()
